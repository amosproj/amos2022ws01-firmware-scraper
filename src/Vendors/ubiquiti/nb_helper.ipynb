# %% [markdown]
# # v1

# %%
# # Import packages

from datetime import datetime
from typing import Optional, Tuple, Union
from urllib.request import urlopen

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import Select, WebDriverWait
from tqdm import tqdm
from webdriver_manager.chrome import ChromeDriverManager

from loguru import logger
from bs4 import BeautifulSoup
import time


from src.Vendors.scraper import Scraper

# # STATICS
VENDOR_URL = 'https://www.ui.com/download/'
DOWNLOAD_PATH = 'downloads/'

# Selenium Webdriver Options, Download Path, Headless, Screensize, Webbrowser Version
options = Options()
options.headless = False

options.add_experimental_option("prefs", {
    "download.default_directory": rf"{DOWNLOAD_PATH}"
})

user_agent = 'foscam Download Assistant/1.0'
options.add_argument(f'user-agent={user_agent}')
# # Initialize Chrome and open Vendor Website

options.add_argument("--window-size=1920,1080")

# %%
# # Class UbiquitiScraper 
class UbiquitiScraper(Scraper):

    def __init__(
            self,
            logger,
            url: str = VENDOR_URL,
            headless: bool = True,
            options: Options = options,
            max_products: int = float('inf')

    ):
        self.headless = headless
        self.url = url
        self.name = "Ubiquiti"
        self.max_products = max_products
        self.driver = webdriver.Chrome(service=Service(
            ChromeDriverManager().install()), options=options)
        self.driver.implicitly_wait(0.5)  # has to be set only once
        self.logger = logger
        self.product_catalog = {}

    def _open_website(self, url: str = '') -> None:
        try:
            if not url:
                url = self.url
            self.driver.get(url)
            self.logger.debug(f'Opened {self.name} website {url}')
        except Exception as e:
            self.logger.error(f"Could not open {self.name} website {url}!")
            self.logger.error(e)

    def _close_website(self) -> None:
        self.driver.close()
        self.logger.debug('Closes Window')

    def _create_product_catalog(self) -> list:
        """parses html and returns a list of tuples with product name and product url

        Args:
            html (_type_): html of current product list

        Returns:
            list: list of tuples with product name and product url
        """

        SELECTOR_PRODUCTS = '//*[@id="downloads"]/div[2]/div[1]'
        self.driver.implicitly_wait(1)
        html = self.driver.find_element(By.XPATH, value=SELECTOR_PRODUCTS).get_attribute('innerHTML')
        product_type_list = BeautifulSoup(html, 'html.parser').find_all('li') # list of product_types
        # list of tuples (product name, product url)
        p_type_and_p_name_tuple = []
        for elem in product_type_list:
            for elem2 in elem('a'):
                try:
                    p_type_and_p_name_tuple.append((elem2.find_all('span')[-1].text, elem2['href']))
                except Exception as e:
                    print(e)
        # list of tuples (product name, product url) to product catalog dict
        for product in p_type_and_p_name_tuple:
            if product[1].startswith('#!'):
                product_type = product[1].replace('#!', '')
                self.product_catalog[product_type] = []
            else:
                self.product_catalog[product_type].append(product[1].replace('#', ''))
        # clean up product catalog, no empty lists like in training, utilities
        self.product_catalog = {k: v for k, v in self.product_catalog.items() if v}
        return self.product_catalog

    def _find_metadata_table(self, product:str) -> None:
        """ find clickable button for see all firmwares then
            find metadata table in html abd return it

        Args:
            product: products name

        Returns:
            _type_: 
        """        
        #SELECTOR_METADATA_TABLE = '/html/body/div[1]/div[1]/div[2]/div[4]/div/main/table'
        #SELECTOR_METADATA_TABLE = '/html/body/div[1]/div[1]/div[2]/div[4]/div/main/table/tbody[2]'
        SELECTOR_METADATA_TABLE = '//*[@id="downloads"]/div[2]/div[4]/div/main/table/tbody[2]'
        #SELECTOR_PAST_FW_BUTTON = '//*[@id="downloads"]/div[2]/div[4]/div/main/table/tbody[2]/tr[12]/td/a'
        SELECTOR_PAST_FW_BUTTON = '//*[@id="downloads"]/div[2]/div[4]/div/main/table/tbody[2]/tr[4]/td/a'
        try:
            self.driver.find_element(
                By.XPATH, value=SELECTOR_PAST_FW_BUTTON).click()
            self.logger.debug('Clicked "SEE PAST FIRMWARE"-button')
        except Exception as e:
            self.logger.debug('No past firmware button, searching for metadata table')
        try:
            product_metadata = self.driver.find_element(
                By.XPATH, value=SELECTOR_METADATA_TABLE).get_attribute('innerHTML')
            self.driver.implicitly_wait(1)
            firmware_list =  BeautifulSoup(product_metadata, 'html.parser').find_all('ul')
            return firmware_list
        except Exception as ex:
            self.logger.debug(f'No metadata table, skip product {product}')
            return None

    def _convert_date(self, date_str: str):
        try:
            return datetime.strptime(date_str, "%Y/%m/%d").strftime("%Y-%m-%d")
        except Exception as ex:
            self.logger.error(f'Could not convert date {date_str}')
            self.logger.error(ex)
            return None

    def scrape_metadata(self):
        """scrapes metadata from foscam website

        Returns:
            list[dict]: list of dicts with metadata
        """
        self._open_website()
        self._create_product_catalog()
        
        metadata = []
        self.logger.debug(f'Iterate over product catalog and scrape metadata')
        for product_type, product_url in self.product_catalog.items():
            if len(metadata) > self.max_products:
                    break
            try:
                self._open_website(f'{VENDOR_URL}{product_url}')
                metadata_html = self._find_metadata_table(product_type, product_url)
                fw_releases_list = BeautifulSoup(metadata_html, 'html.parser').find_all('ul')
                for fw_release in fw_releases_list:
                    metadata_current = fw_release.find_all('td')
                    tmp_metadata_dict = {'manufacturer': self.name,
                                                    'version': metadata_current[0].text,
                                                    'product_type': product_type, 
                                                    'product_name': product_url,
                                                    'url': f'{VENDOR_URL}{product_url}',
                                                    'checksum_scraped': None, # not available
                                                    'download_link': f"{VENDOR_URL}{metadata_current[-1].find_all('a')[0]['href']}",
                                                    'release_date': self._convert_date(metadata_current[1].text),
                                                    "additional_data": {} # nothing valuable
                                                    }
                                                    
                    metadata.append(tmp_metadata_dict)
                print(f'Finished scraping {product_type=}, {product_url=}')
            except Exception as ex:
                print('{product}, {product_url} is missing crucial data')
                print(ex)
                pass
            time.sleep(1)
        self.driver.quit()
        return metadata

# %%
scraper = UbiquitiScraper(logger)

# %%
scraper._open_website()
# Out:
# 2023-01-14 18:13:58.272 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/

# %%
product_catalog = scraper._create_product_catalog()
product_catalog
# Out:
# list index out of range
# list index out of range
# {'airmax-ac': ['gigabeam',
#   'isostation-ac',
#   'prismstation-ac',
#   'litebeam-ac',
#   'litebeam-ac-gen2',
#   'nanobeam-ac',
#   'nanobeam-ac-gen2',
#   'nanostation-ac',
#   'powerbeam-ac',
#   'powerbeam-ac-gen2',
#   'powerbeam-ac-iso',
#   'rocket-prism-ac',
#   'liteap-ac',
#   'rocket-ac',
#   'bullet-ac',
#   'airprism-sector',
#   'airmax-ac-sector-antenna',
#   'rocketdish-ac-antenna',
#   'horn-5',
#   'monsterdish-antenna',
#   'gigabeam',
#   'isostation-ac',
#   'prismstation-ac',
#   'litebeam-ac',
#   'litebeam-ac-gen2',
#   'nanobeam-ac',
#   'nanobeam-ac-gen2',
#   'nanostation-ac',
#   'powerbeam-ac',
#   'powerbeam-ac-gen2',
#   'powerbeam-ac-iso',
#   'rocket-prism-ac',
#   'liteap-ac',
#   'rocket-ac',
#   'bullet-ac',
#   'airprism-sector',
#   'airmax-ac-sector-antenna',
#   'rocketdish-ac-antenna',
#   'horn-5',
#   'monsterdish-antenna'],
#  'airmax-m': ['isostation-m',
#   'airgridm',
#   'litebeam-m5',
#   'nanobeamm',
#   'powerbeam',
#   'powerbeam-m5-iso',
#   'bulletm',
#   'nanostationm',
#   'nanobridgem',
#   'powerbridge-m10',
#   'picostationm',
#   'powerbridgem',
#   'rocketm',
#   'crmpoint',
#   'rocket-m-titanium',
#   'rocketdish-antenna',
#   'rocketdish-lw',
#   'airmax-sector-antenna',
#   'airmax-omni-antenna',
#   'airmax-yagi-antenna',
#   'isobeam',
#   'isostation-m',
#   'airgridm',
#   'litebeam-m5',
#   'nanobeamm',
#   'powerbeam',
#   'powerbeam-m5-iso',
#   'bulletm',
#   'nanostationm',
#   'nanobridgem',
#   'powerbridge-m10',
#   'picostationm',
#   'powerbridgem',
#   'rocketm',
#   'crmpoint',
#   'rocket-m-titanium',
#   'rocketdish-antenna',
#   'rocketdish-lw',
#   'airmax-sector-antenna',
#   'airmax-omni-antenna',
#   'airmax-yagi-antenna',
#   'isobeam'],
#  'airmax-legacy': ['airgrid-m-legacy-models',
#   'airrouter',
#   'airwire',
#   'bullet-legacy-models',
#   'litestation-m5',
#   'ls2',
#   'ls5',
#   'ministation',
#   'nanostation',
#   'nanostationloco',
#   'picostation-2',
#   'picostation5',
#   'powerapn',
#   'powerstation',
#   'sr2',
#   'sr4',
#   'sr4c',
#   'sr5',
#   'sr9',
#   'src',
#   'ub5',
#   'wifistation',
#   'wispstation5',
#   'wispstationm5',
#   'xr3',
#   'xr4',
#   'xr5',
#   'xr7',
#   'xr9',
#   'airgrid-m-legacy-models',
#   'airrouter',
#   'airwire',
#   'bullet-legacy-models',
#   'litestation-m5',
#   'ls2',
#   'ls5',
#   'ministation',
#   'nanostation',
#   'nanostationloco',
#   'picostation-2',
#   'picostation5',
#   'powerapn',
#   'powerstation',
#   'sr2',
#   'sr4',
#   'sr4c',
#   'sr5',
#   'sr9',
#   'src',
#   'ub5',
#   'wifistation',
#   'wispstation5',
#   'wispstationm5',
#   'xr3',
#   'xr4',
#   'xr5',
#   'xr7',
#   'xr9'],
#  'airfiber': ['airfiber-11',
#   'airfiber24',
#   'airfiber24-hd',
#   'airfiber5',
#   'airfiber5xhd',
#   'airfiber-60',
#   'airfiber-60-hd',
#   'airfiber-60-lr',
#   'airfiber-60-xg',
#   'airfiber-60-xr',
#   'airfiber-nxn',
#   'airfiberx',
#   'airfiberx-antenna',
#   'airfiber-11',
#   'airfiber24',
#   'airfiber24-hd',
#   'airfiber5',
#   'airfiber5xhd',
#   'airfiber-60',
#   'airfiber-60-hd',
#   'airfiber-60-lr',
#   'airfiber-60-xg',
#   'airfiber-60-xr',
#   'airfiber-nxn',
#   'airfiberx',
#   'airfiberx-antenna'],
#  'ltu': ['ltu-instant',
#   'ltu-lite',
#   'ltu-lr',
#   'ltu-pro',
#   'ltu-rocket',
#   'ltu-xr',
#   'ltu-instant',
#   'ltu-lite',
#   'ltu-lr',
#   'ltu-pro',
#   'ltu-rocket',
#   'ltu-xr'],
#  'ufiber': ['ufiber-ae',
#   'ufiber-instant',
#   'ufiber-loco',
#   'ufiber-nano-g',
#   'ufiber-olt',
#   'ufiber-olt-4',
#   'ufiber-wifi',
#   'ufiber-wifi6-gpon-cpe',
#   'ufiber-ae',
#   'ufiber-instant',
#   'ufiber-loco',
#   'ufiber-nano-g',
#   'ufiber-olt',
#   'ufiber-olt-4',
#   'ufiber-wifi',
#   'ufiber-wifi6-gpon-cpe'],
#  'edgemax': ['edgepoint',
#   'edgerouter',
#   'edgerouter-10x',
#   'edgerouter-12',
#   'edgerouter-12p',
#   'edgerouter-4',
#   'edgerouter-6p',
#   'edgerouter-infinity',
#   'edgerouter-lite',
#   'edgerouter-poe',
#   'edgerouter-pro',
#   'edgerouter-x',
#   'edgerouter-x-sfp',
#   'edgeswitch',
#   'edgeswitch-10x',
#   'edgeswitch-10xp',
#   'edgeswitch-12f',
#   'edgeswitch-16-xg',
#   'edgeswitch-18x',
#   'edgeswitch-8-150w',
#   'edgeswitch-lite',
#   'edgeswitch-xp',
#   'edgepoint',
#   'edgerouter',
#   'edgerouter-10x',
#   'edgerouter-12',
#   'edgerouter-12p',
#   'edgerouter-4',
#   'edgerouter-6p',
#   'edgerouter-infinity',
#   'edgerouter-lite',
#   'edgerouter-poe',
#   'edgerouter-pro',
#   'edgerouter-x',
#   'edgerouter-x-sfp',
#   'edgeswitch',
#   'edgeswitch-10x',
#   'edgeswitch-10xp',
#   'edgeswitch-12f',
#   'edgeswitch-16-xg',
#   'edgeswitch-18x',
#   'edgeswitch-8-150w',
#   'edgeswitch-lite',
#   'edgeswitch-xp'],
#  'mfi': ['inwall', 'mport', 'mpower', 'inwall', 'mport', 'mpower'],
#  'sunmax': ['sunmax',
#   'sunmax-solarpoint',
#   'sunmax-solarswitch',
#   'sunmax',
#   'sunmax-solarpoint',
#   'sunmax-solarswitch'],
#  'unifi': ['unifi-6-enterprise',
#   'unifi-6-extender',
#   'unifi-6-lite-ap',
#   'unifi-6-lr-ap',
#   'unifi-6-mesh',
#   'unifi-6-pro-ap',
#   'unifi-ac',
#   'unifi-ac-wall',
#   'unifi-ap',
#   'unifi-ap-ac',
#   'unifi-ap-ac-edu',
#   'unifi-ap-ac-lite',
#   'unifi-ap-ac-lr',
#   'unifi-ap-ac-outdoor',
#   'unifi-ap-ac-pro',
#   'unifi-ap-beacon-hd',
#   'unifi-ap-hd',
#   'unifi-ap-outdoor',
#   'unifi-ap-shd',
#   'unifi-ap-wall',
#   'unifi-ap-wifi-6-wall',
#   'unifi-ap-xg',
#   'unifi-building-building-bridge',
#   'unifi-building-building-bridge-xg',
#   'unifi-cloud-key',
#   'unifi-cloud-key-gen2',
#   'unifi-dream-machine',
#   'unifi-dream-machine-pro',
#   'unifi-dream-machine-se',
#   'unifi-dream-router',
#   'unifi-flex-hd',
#   'unifi-hd-wall',
#   'unifi-mesh',
#   'unifi-mesh-antenna',
#   'unifi-nanohd',
#   'unifi-wifi-basestation-xg',
#   'unifi-legacy',
#   'unifi-6-enterprise',
#   'unifi-6-extender',
#   'unifi-6-lite-ap',
#   'unifi-6-lr-ap',
#   'unifi-6-mesh',
#   'unifi-6-pro-ap',
#   'unifi-ac',
#   'unifi-ac-wall',
#   'unifi-ap',
#   'unifi-ap-ac',
#   'unifi-ap-ac-edu',
#   'unifi-ap-ac-lite',
#   'unifi-ap-ac-lr',
#   'unifi-ap-ac-outdoor',
#   'unifi-ap-ac-pro',
#   'unifi-ap-beacon-hd',
#   'unifi-ap-hd',
#   'unifi-ap-outdoor',
#   'unifi-ap-shd',
#   'unifi-ap-wall',
#   'unifi-ap-wifi-6-wall',
#   'unifi-ap-xg',
#   'unifi-building-building-bridge',
#   'unifi-building-building-bridge-xg',
#   'unifi-cloud-key',
#   'unifi-cloud-key-gen2',
#   'unifi-dream-machine',
#   'unifi-dream-machine-pro',
#   'unifi-dream-machine-se',
#   'unifi-dream-router',
#   'unifi-flex-hd',
#   'unifi-hd-wall',
#   'unifi-mesh',
#   'unifi-mesh-antenna',
#   'unifi-nanohd',
#   'unifi-wifi-basestation-xg',
#   'unifi-legacy'],
#  'wave': ['wave-access-point',
#   'wave-long-range',
#   'wave-nano',
#   'wave-access-point',
#   'wave-long-range',
#   'wave-nano'],
#  'unifi-protect': ['unifi-protect-g3-instant-camera',
#   'unifi-protect-g4-dome-camera',
#   'unifi-protect-g4-doorbell',
#   'unifi-protect-g4-instant-camera',
#   'unifi-protect-g4-ptz',
#   'unifi-protect-nvr',
#   'unifi-protect-nvr-pro',
#   'unifi-protect-viewport-poe',
#   'unifi-video-camera-g3',
#   'unifi-video-camera-g3-dome',
#   'unifi-video-camera-g3-micro',
#   'unifi-video-camera-g3-pro',
#   'unifi-video-camera-g4-bullet',
#   'unifi-video-camera-g4-pro',
#   'unifi-video-g3-flex-camera',
#   'unifi-protect-legacy',
#   'unifi-protect-g3-instant-camera',
#   'unifi-protect-g4-dome-camera',
#   'unifi-protect-g4-doorbell',
#   'unifi-protect-g4-instant-camera',
#   'unifi-protect-g4-ptz',
#   'unifi-protect-nvr',
#   'unifi-protect-nvr-pro',
#   'unifi-protect-viewport-poe',
#   'unifi-video-camera-g3',
#   'unifi-video-camera-g3-dome',
#   'unifi-video-camera-g3-micro',
#   'unifi-video-camera-g3-pro',
#   'unifi-video-camera-g4-bullet',
#   'unifi-video-camera-g4-pro',
#   'unifi-video-g3-flex-camera',
#   'unifi-protect-legacy'],
#  'unifi-access': ['unifi-access-card',
#   'unifi-access-hub',
#   'unifi-access-lite',
#   'unifi-access-pro',
#   'unifi-access-starter-kit',
#   'unifi-access-card',
#   'unifi-access-hub',
#   'unifi-access-lite',
#   'unifi-access-pro',
#   'unifi-access-starter-kit'],
#  'unifi-switching-routing': ['unifi-next-generation-gateway-pro',
#   'unifi-security-gateway-pro-4',
#   'unifi-security-gateway-xg-8',
#   'unifi-xg-server',
#   'usg',
#   'unifi-industrial-switch',
#   'unifi-lte',
#   'unifi-lte-pro',
#   'unifi-power-distribution-professional',
#   'unifi-redundant-power-system',
#   'unifi-switch-16-150w',
#   'unifi-switch-16-poe',
#   'unifi-switch-16-poe-lite',
#   'unifi-switch-16-xg',
#   'unifi-switch-24',
#   'unifi-switch-2448',
#   'unifi-switch-24-poe',
#   'unifi-switch-48',
#   'unifi-switch-48-poe',
#   'unifi-switch-8',
#   'unifi-switch-8-150w',
#   'unifi-switch-8-60w',
#   'unifi-switch-aggregation',
#   'unifi-switch-aggregation-pro',
#   'unifi-switch-enterprise-24-poe',
#   'unifi-switch-enterprise-48-poe',
#   'unifi-switch-enterprise-8-poe',
#   'unifi-switch-enterprise-xg-24',
#   'unifi-switch-flex',
#   'unifi-switch-flex-mini',
#   'unifi-switch-flex-xg',
#   'unifi-switch-l2-poe-2448',
#   'unifi-switch-lite-8-poe',
#   'unifi-switch-mission-critical',
#   'unifi-switch-poe',
#   'unifi-switch-pro-24',
#   'unifi-switch-pro-24-poe',
#   'unifi-switch-pro-48',
#   'unifi-switch-pro-48-poe',
#   'unifi-switch-xg-6poe',
#   'unifi-next-generation-gateway-pro',
#   'unifi-security-gateway-pro-4',
#   'unifi-security-gateway-xg-8',
#   'unifi-xg-server',
#   'usg',
#   'unifi-industrial-switch',
#   'unifi-lte',
#   'unifi-lte-pro',
#   'unifi-power-distribution-professional',
#   'unifi-redundant-power-system',
#   'unifi-switch-16-150w',
#   'unifi-switch-16-poe',
#   'unifi-switch-16-poe-lite',
#   'unifi-switch-16-xg',
#   'unifi-switch-24',
#   'unifi-switch-2448',
#   'unifi-switch-24-poe',
#   'unifi-switch-48',
#   'unifi-switch-48-poe',
#   'unifi-switch-8',
#   'unifi-switch-8-150w',
#   'unifi-switch-8-60w',
#   'unifi-switch-aggregation',
#   'unifi-switch-aggregation-pro',
#   'unifi-switch-enterprise-24-poe',
#   'unifi-switch-enterprise-48-poe',
#   'unifi-switch-enterprise-8-poe',
#   'unifi-switch-enterprise-xg-24',
#   'unifi-switch-flex',
#   'unifi-switch-flex-mini',
#   'unifi-switch-flex-xg',
#   'unifi-switch-l2-poe-2448',
#   'unifi-switch-lite-8-poe',
#   'unifi-switch-mission-critical',
#   'unifi-switch-poe',
#   'unifi-switch-pro-24',
#   'unifi-switch-pro-24-poe',
#   'unifi-switch-pro-48',
#   'unifi-switch-pro-48-poe',
#   'unifi-switch-xg-6poe'],
#  'unifi-talk': ['unifi-phone-touch',
#   'unifi-phone-touch-max',
#   'unifi-talk-phone-flex',
#   'unifi-phone-touch',
#   'unifi-phone-touch-max',
#   'unifi-talk-phone-flex'],
#  'unifi-led': ['unifi-dimmer-switch',
#   'unifi-led',
#   'unifi-dimmer-switch',
#   'unifi-led'],
#  'accessories': ['60g-precision-alignment-mount',
#   'aircube',
#   'airgateway',
#   'ceiling-mount',
#   'edgepower',
#   'edgepower-24v',
#   'edgepower-54v',
#   'ethernet-surge-protector',
#   'fiber-modules-cable',
#   'fiber-poe-accessory',
#   'g4-bullet-ir-range-extender',
#   'gpon-network-accessories',
#   'instant-8023af-adapters',
#   'ir-range-extender',
#   'isobeam-nanobeam',
#   'nanobeam-window-mount',
#   'nanoswitch',
#   'poe-adapters',
#   'powercable',
#   'powermodule',
#   'precision-alignment-kit',
#   'quick-mount',
#   'toughcable',
#   'toughswitch',
#   'u-installer',
#   'unifi-smart-power-plug',
#   'unifi-smartpower-strip',
#   'uvc-pro-cable-accessory',
#   'uvc-pro-large-pole-mount',
#   '60g-precision-alignment-mount',
#   'aircube',
#   'airgateway',
#   'ceiling-mount',
#   'edgepower',
#   'edgepower-24v',
#   'edgepower-54v',
#   'ethernet-surge-protector',
#   'fiber-modules-cable',
#   'fiber-poe-accessory',
#   'g4-bullet-ir-range-extender',
#   'gpon-network-accessories',
#   'instant-8023af-adapters',
#   'ir-range-extender',
#   'isobeam-nanobeam',
#   'nanobeam-window-mount',
#   'nanoswitch',
#   'poe-adapters',
#   'powercable',
#   'powermodule',
#   'precision-alignment-kit',
#   'quick-mount',
#   'toughcable',
#   'toughswitch',
#   'u-installer',
#   'unifi-smart-power-plug',
#   'unifi-smartpower-strip',
#   'uvc-pro-cable-accessory',
#   'uvc-pro-large-pole-mount']}

# %%
def accept_cookies():
    """_summary_
    """

# %%
# scrape metadata
ll = []
for product_type, products in tqdm(product_catalog.items()):
    # i.e. https://www.ui.com/download/airmax-ac/powerbeam-ac
    scraper._open_website(f'{VENDOR_URL}{product_type}')
    scraper.driver.implicitly_wait(5)
        '//*[@id="reveal-eula"]'
    # scrape metadata # parse metadata
    firmware_list = scraper._find_metadata_table(product_type)
    ll.append((product_type,firmware_list))
    if firmware_list:
        scraper.logger.debug(f'Found metadata table for {product_type}, {len(firmware_list)} entries')
    else:
        scraper.logger.debug(f'No metadata table for {product_type}')
        continue
# Out:
#   0%|          | 0/17 [00:00<?, ?it/s]2023-01-14 18:14:01.279 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/airmax-ac
# 2023-01-14 18:14:02.760 | DEBUG    | __main__:_find_metadata_table:89 - Clicked "SEE PAST FIRMWARE"-button
# 2023-01-14 18:14:02.811 | DEBUG    | __main__:<module>:10 - Found metadata table for airmax-ac, 5 entries
#   6%|▌         | 1/17 [00:04<01:07,  4.19s/it]2023-01-14 18:14:05.681 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/airmax-m
# 2023-01-14 18:14:07.363 | DEBUG    | __main__:_find_metadata_table:89 - Clicked "SEE PAST FIRMWARE"-button
# 2023-01-14 18:14:07.398 | DEBUG    | __main__:<module>:10 - Found metadata table for airmax-m, 3 entries
#  12%|█▏        | 2/17 [00:08<01:06,  4.42s/it]2023-01-14 18:14:10.011 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/airmax-legacy
# 2023-01-14 18:14:11.543 | DEBUG    | __main__:_find_metadata_table:89 - Clicked "SEE PAST FIRMWARE"-button
# 2023-01-14 18:14:11.583 | DEBUG    | __main__:<module>:10 - Found metadata table for airmax-legacy, 7 entries
#  18%|█▊        | 3/17 [00:12<01:00,  4.31s/it]2023-01-14 18:14:13.648 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/airfiber
# 2023-01-14 18:14:14.677 | DEBUG    | __main__:_find_metadata_table:89 - Clicked "SEE PAST FIRMWARE"-button
# 2023-01-14 18:14:14.785 | DEBUG    | __main__:<module>:10 - Found metadata table for airfiber, 10 entries
#  24%|██▎       | 4/17 [00:16<00:50,  3.88s/it]2023-01-14 18:14:16.861 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/ltu
# 2023-01-14 18:14:17.595 | DEBUG    | __main__:_find_metadata_table:89 - Clicked "SEE PAST FIRMWARE"-button
# 2023-01-14 18:14:17.626 | DEBUG    | __main__:<module>:10 - Found metadata table for ltu, 2 entries
#  29%|██▉       | 5/17 [00:19<00:42,  3.50s/it]2023-01-14 18:14:20.017 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/ufiber
# 2023-01-14 18:14:20.860 | DEBUG    | __main__:_find_metadata_table:89 - Clicked "SEE PAST FIRMWARE"-button
# 2023-01-14 18:14:20.889 | DEBUG    | __main__:<module>:10 - Found metadata table for ufiber, 3 entries
#  35%|███▌      | 6/17 [00:22<00:37,  3.42s/it]2023-01-14 18:14:23.052 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/edgemax
# 2023-01-14 18:14:24.600 | DEBUG    | __main__:_find_metadata_table:89 - Clicked "SEE PAST FIRMWARE"-button
# 2023-01-14 18:14:24.682 | DEBUG    | __main__:<module>:10 - Found metadata table for edgemax, 11 entries
#  41%|████      | 7/17 [00:26<00:35,  3.54s/it]2023-01-14 18:14:26.861 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/mfi
# 2023-01-14 18:14:27.561 | DEBUG    | __main__:_find_metadata_table:89 - Clicked "SEE PAST FIRMWARE"-button
# 2023-01-14 18:14:27.598 | DEBUG    | __main__:<module>:10 - Found metadata table for mfi, 4 entries
#  47%|████▋     | 8/17 [00:28<00:30,  3.34s/it]2023-01-14 18:14:29.589 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/sunmax
# 2023-01-14 18:14:30.204 | DEBUG    | __main__:_find_metadata_table:89 - Clicked "SEE PAST FIRMWARE"-button
# 2023-01-14 18:14:30.228 | DEBUG    | __main__:<module>:10 - Found metadata table for sunmax, 2 entries
#  53%|█████▎    | 9/17 [00:31<00:24,  3.12s/it]2023-01-14 18:14:32.685 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/unifi
# 2023-01-14 18:14:35.869 | DEBUG    | __main__:_find_metadata_table:89 - Clicked "SEE PAST FIRMWARE"-button
# 2023-01-14 18:14:35.970 | DEBUG    | __main__:<module>:10 - Found metadata table for unifi, 20 entries
#  59%|█████▉    | 10/17 [00:37<00:27,  3.93s/it]2023-01-14 18:14:38.398 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/wave
# 2023-01-14 18:14:38.901 | DEBUG    | __main__:_find_metadata_table:89 - Clicked "SEE PAST FIRMWARE"-button
# 2023-01-14 18:14:38.929 | DEBUG    | __main__:<module>:10 - Found metadata table for wave, 2 entries
#  65%|██████▍   | 11/17 [00:40<00:21,  3.63s/it]2023-01-14 18:14:41.001 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/unifi-protect
# 2023-01-14 18:14:42.778 | DEBUG    | __main__:_find_metadata_table:89 - Clicked "SEE PAST FIRMWARE"-button
# 2023-01-14 18:14:42.824 | DEBUG    | __main__:<module>:10 - Found metadata table for unifi-protect, 7 entries
#  71%|███████   | 12/17 [00:44<00:18,  3.71s/it]2023-01-14 18:14:45.057 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/unifi-access
# 2023-01-14 18:14:50.107 | DEBUG    | __main__:_find_metadata_table:91 - No past firmware button, searching for metadata table
# 2023-01-14 18:14:50.129 | DEBUG    | __main__:<module>:12 - No metadata table for unifi-access
#  76%|███████▋  | 13/17 [00:51<00:19,  4.80s/it]2023-01-14 18:14:52.380 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/unifi-switching-routing
# 2023-01-14 18:14:54.954 | DEBUG    | __main__:_find_metadata_table:89 - Clicked "SEE PAST FIRMWARE"-button
# 2023-01-14 18:14:55.035 | DEBUG    | __main__:<module>:10 - Found metadata table for unifi-switching-routing, 18 entries
#  82%|████████▏ | 14/17 [00:56<00:14,  4.83s/it]2023-01-14 18:14:57.060 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/unifi-talk
# 2023-01-14 18:15:02.107 | DEBUG    | __main__:_find_metadata_table:91 - No past firmware button, searching for metadata table
# 2023-01-14 18:15:02.127 | DEBUG    | __main__:<module>:12 - No metadata table for unifi-talk
#  88%|████████▊ | 15/17 [01:03<00:11,  5.51s/it]2023-01-14 18:15:04.738 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/unifi-led
# 2023-01-14 18:15:09.765 | DEBUG    | __main__:_find_metadata_table:91 - No past firmware button, searching for metadata table
# 2023-01-14 18:15:09.786 | DEBUG    | __main__:<module>:12 - No metadata table for unifi-led
#  94%|█████████▍| 16/17 [01:11<00:06,  6.16s/it]2023-01-14 18:15:12.041 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/accessories
# 2023-01-14 18:15:13.257 | DEBUG    | __main__:_find_metadata_table:89 - Clicked "SEE PAST FIRMWARE"-button
# 2023-01-14 18:15:13.323 | DEBUG    | __main__:<module>:10 - Found metadata table for accessories, 9 entries
# 100%|██████████| 17/17 [01:14<00:00,  4.39s/it]

# %%
for l in ll:
    print(l[0], len(l[1]))
# Out:
# airmax-ac 5
# airmax-m 3
# airmax-legacy 7
# airfiber 10
# ltu 2
# ufiber 3
# edgemax 11
# mfi 4
# sunmax 2
# unifi 20
# wave 2
# unifi-protect 7
# unifi-access 0
# unifi-switching-routing 18
# unifi-talk 0
# unifi-led 0
# accessories 9

# %%
ll = []
# for product type, product names
for k, values in product_catalog.items():
    # for each product / page
    for v in values:
        # scrape metadata # parse metadata
        metadata_table = scraper._find_metadata_table(k, v)
        firmware_list = BeautifulSoup(metadata_table, 'html.parser').find_all('ul')
        # for every firmware in table
        for fw in firmware_list:
            fw_dict = {}
            attributes_list = fw.get_text().split('\n\n')
            for str_elem in attributes_list:
                try:
                    fw_dict[str_elem.split(':')[0].strip()] = str_elem.split(':')[1].strip()
                except Exception as ex:
                    if 'checksum' in str_elem:
                        fw_dict['checksum'] = str_elem.split('checksum')[1].strip()
                    else:
                        print(ex)
                    pass
            #print()
# Out:
# 2022-12-17 15:32:00.174 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/airmax-ac/gigabeam
# 2022-12-17 15:32:00.680 | DEBUG    | __main__:_find_metadata_table:90 - Clicked See past firmware button
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# 2022-12-17 15:32:03.839 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/airmax-ac/isostation-ac
# 2022-12-17 15:32:04.487 | DEBUG    | __main__:_find_metadata_table:90 - Clicked See past firmware button
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# 2022-12-17 15:32:07.633 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/airmax-ac/prismstation-ac
# 2022-12-17 15:32:08.662 | DEBUG    | __main__:_find_metadata_table:90 - Clicked See past firmware button
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# 2022-12-17 15:32:12.014 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/airmax-ac/litebeam-ac
# 2022-12-17 15:32:12.762 | DEBUG    | __main__:_find_metadata_table:90 - Clicked See past firmware button
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [90], line 7
#       3 for k, values in product_catalog.items():
#       4     # for each product
#       5     for v in values:
#       6         # scrape metadata
# ----> 7         metadata_table = scraper._find_metadata_table(k, v)
#       8         # parse metadata
#       9         firmware_list = BeautifulSoup(metadata_table, 'html.parser').find_all('ul')
#
# Cell In [10], line 82, in UbiquitiScraper._find_metadata_table(self, product_type, product_url)
#      71 """ find clickable button for see all firmwares then
#      72     find metadata table in html abd return it
#      73
#    (...)
#      79     _type_:
#      80 """
#      81 # i.e. https://www.ui.com/download/airmax-ac/powerbeam-ac
# ---> 82 self._open_website(f'{VENDOR_URL}{product_type}/{product_url}')
#      83 #SELECTOR_METADATA_TABLE = '/html/body/div[1]/div[1]/div[2]/div[4]/div/main/table'
#      84 SELECTOR_METADATA_TABLE = '/html/body/div[1]/div[1]/div[2]/div[4]/div/main/table/tbody[2]'
#
# Cell In [10], line 27, in UbiquitiScraper._open_website(self, url)
#      25     if not url:
#      26         url = self.url
# ---> 27     self.driver.get(url)
#      28     self.logger.debug(f'Opened {self.name} website {url}')
#      29 except Exception as e:
#
# File /usr/local/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:455, in WebDriver.get(self, url)
#     451 def get(self, url: str) -> None:
#     452     """
#     453     Loads a web page in the current browser session.
#     454     """
# --> 455     self.execute(Command.GET, {"url": url})
#
# File /usr/local/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:442, in WebDriver.execute(self, driver_command, params)
#     439     elif "sessionId" not in params:
#     440         params["sessionId"] = self.session_id
# --> 442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
#     444     self.error_handler.check_response(response)
#
# File /usr/local/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py:294, in RemoteConnection.execute(self, command, params)
#     292 data = utils.dump_json(params)
#     293 url = f"{self._url}{path}"
# --> 294 return self._request(command_info[0], url, body=data)
#
# File /usr/local/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py:316, in RemoteConnection._request(self, method, url, body)
#     313     body = None
#     315 if self.keep_alive:
# --> 316     response = self._conn.request(method, url, body=body, headers=headers)
#     317     statuscode = response.status
#     318 else:
#
# File /usr/local/lib/python3.10/site-packages/urllib3/request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File /usr/local/lib/python3.10/site-packages/urllib3/request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File /usr/local/lib/python3.10/site-packages/urllib3/poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File /usr/local/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /usr/local/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /usr/local/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /usr/local/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File /usr/local/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/local/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/local/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# Out:
# 2022-12-17 21:15:27.144 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/airmax-ac/powerbeam-ac
# 2022-12-17 21:15:27.819 | DEBUG    | __main__:_find_metadata_table:90 - Clicked See past firmware button

# %%
metadata_keys = ['manufacturer','product_name','product_type','version','release_date','download_link','file_path','checksum_local','checksum_scraped','emba_tested','emba_report_path','embark_report_link','additional_data']
ll = []
for product_type, products in product_catalog.items():
    for product in products:
        try:
            metadata_table = scraper._find_metadata_table(product_type, product)
            firmware_list = BeautifulSoup(metadata_table, 'html.parser').find_all('ul')
            for fw in firmware_list:
                fw_dict = dict.fromkeys(metadata_keys)
                for fw_metadata_elem in fw.find_all('li'):
                    if 'Filename' in fw_metadata_elem.get_text():
                        fw_dict['file_path'] = fw_metadata_elem.findAll('div')[-1].get_text()
                    elif 'Version' in fw_metadata_elem.get_text():
                        fw_dict['version'] = fw_metadata_elem.findAll('div')[-1].get_text()
                    elif 'Products' in fw_metadata_elem.get_text():
                        fw_dict['additional_data'] = {'products': fw_metadata_elem.findAll('div')[-1].get_text()}
                    elif 'MD5 checksum' in fw_metadata_elem.get_text():
                        fw_dict['checksum_scraped'] = fw_metadata_elem.findAll('div')[-1].get_text().replace('MD5 checksum ', '').strip()
                fw_dict['manufacturer'] = 'Ubiquiti'
                fw_dict['product_name'] = product
                fw_dict['product_type'] = product_type
                ll.append(fw_dict)
        except Exception as ex:
            print(ex)
            pass
# Out:
# 2022-12-17 21:50:16.429 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/airmax-ac/gigabeam
# 2022-12-17 21:50:16.699 | DEBUG    | __main__:_find_metadata_table:90 - Clicked See past firmware button
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [184], line 6
#       4 for product in products:
#       5     try:
# ----> 6         metadata_table = scraper._find_metadata_table(product_type, product)
#       7         firmware_list = BeautifulSoup(metadata_table, 'html.parser').find_all('ul')
#       8         for fw in firmware_list:
#
# Cell In [170], line 82, in UbiquitiScraper._find_metadata_table(self, product_type, product_url)
#      71 """ find clickable button for see all firmwares then
#      72     find metadata table in html abd return it
#      73
#    (...)
#      79     _type_:
#      80 """
#      81 # i.e. https://www.ui.com/download/airmax-ac/powerbeam-ac
# ---> 82 self._open_website(f'{VENDOR_URL}{product_type}/{product_url}')
#      83 #SELECTOR_METADATA_TABLE = '/html/body/div[1]/div[1]/div[2]/div[4]/div/main/table'
#      84 SELECTOR_METADATA_TABLE = '/html/body/div[1]/div[1]/div[2]/div[4]/div/main/table/tbody[2]'
#
# Cell In [170], line 27, in UbiquitiScraper._open_website(self, url)
#      25     if not url:
#      26         url = self.url
# ---> 27     self.driver.get(url)
#      28     self.logger.debug(f'Opened {self.name} website {url}')
#      29 except Exception as e:
#
# File /usr/local/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:455, in WebDriver.get(self, url)
#     451 def get(self, url: str) -> None:
#     452     """
#     453     Loads a web page in the current browser session.
#     454     """
# --> 455     self.execute(Command.GET, {"url": url})
#
# File /usr/local/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:442, in WebDriver.execute(self, driver_command, params)
#     439     elif "sessionId" not in params:
#     440         params["sessionId"] = self.session_id
# --> 442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
#     444     self.error_handler.check_response(response)
#
# File /usr/local/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py:294, in RemoteConnection.execute(self, command, params)
#     292 data = utils.dump_json(params)
#     293 url = f"{self._url}{path}"
# --> 294 return self._request(command_info[0], url, body=data)
#
# File /usr/local/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py:316, in RemoteConnection._request(self, method, url, body)
#     313     body = None
#     315 if self.keep_alive:
# --> 316     response = self._conn.request(method, url, body=body, headers=headers)
#     317     statuscode = response.status
#     318 else:
#
# File /usr/local/lib/python3.10/site-packages/urllib3/request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File /usr/local/lib/python3.10/site-packages/urllib3/request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File /usr/local/lib/python3.10/site-packages/urllib3/poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File /usr/local/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /usr/local/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /usr/local/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /usr/local/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File /usr/local/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/local/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/local/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
metadata_keys = ['manufacturer','product_name','product_type','version','release_date','download_link','file_path','checksum_local','checksum_scraped','emba_tested','emba_report_path','embark_report_link','additional_data']
ll = []
for product_type, products in product_catalog.items():
    for product in products[:10]:
        metadata_table = scraper._find_metadata_table(product_type, product)
        firmware_list = BeautifulSoup(metadata_table, 'html.parser').find_all('ul')
        for fw in firmware_list:
            fw_dict = dict.fromkeys(metadata_keys)
            for fw_metadata_elem in fw.find_all('li'):
                print(fw_metadata_elem)
                '//*[@id="downloads"]/div[2]/div[4]/div/main/table/tbody[2]/tr[2]/td[4]'
# Out:
# 2022-12-17 22:53:02.123 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/airmax-ac/gigabeam
# 2022-12-17 22:53:02.546 | DEBUG    | __main__:_find_metadata_table:90 - Clicked See past firmware button
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">GBE.v1.4.1.1bf05681.221028.1153.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v1.4.1</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">11.57MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">GBE</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 1b67fd49247d811cede8aeff7bf2b061
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">GBE.v1.4.0.1e71455a.210726.1326.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v1.4.0</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">11.5MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">GBE</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 47c9ce60f95f7018297c76af75ac3056
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">GBE.v1.3.0.492789c1.210406.0813.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v1.3.0</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">11.78 MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">GBE</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 81f8dc779f424512c46fe362ce26be57
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">GBE.v1.2.0.ec5ea39c.201015.1407.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v1.2.0</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">11.7 MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">GBE</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 730066aeed53dab323f090973f5cb7a6
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">GBE.v0.11.1-cs.f16f621c.200826.1546.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v0.11.1</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">10.56MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">GBE</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 99d7216db91e4c54da426d28d4cf43d0
#                         </div>
# </li>
# 2022-12-17 22:53:05.394 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/airmax-ac/isostation-ac
# 2022-12-17 22:53:06.430 | DEBUG    | __main__:_find_metadata_table:90 - Clicked See past firmware button
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.7.11.46972.220614.0420.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.7.11</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.7MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 855887a0a61c93e05c9448b2a3aca4d2
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.7.9.46843.220329.1728.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.7.9</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.7MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 8f855b17ee0995c67dc323b3394e631b
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.7.8.46705.220201.1819.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.7.8</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.7MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum bc6b35314110a4278ecd3dfeb8b28a52
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.7.7.46663.220119.1718.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.7.7</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.7MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 634210d31b971d57d6cf46db5c944bd2
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.7.5.45783.210720.1004.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.7.5</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.29MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2, PBE-5AC-ISO-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 02CB1D65ED9BF9240D6FA853A595F197
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.7.4.45112.210415.1103.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.7.4</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.7MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2, PBE-5AC-ISO-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum bb8c08affb1d248201fb8aa3764890d8
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.7.1.42832.200623.1641.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.7.1</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.2MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2, PBE-5AC-ISO-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 9115c4bb55848ef881edb76c74e6575e
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.7.0.42152.200203.1256.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.7.0</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">8.8MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2, PBE-5AC-ISO-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum d1531fcd5991af73047fab83c0d016cf
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.6.2.41239.190822.1633.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.6.2</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.0 MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2, PBE-5AC-ISO-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 494d0bc0307e318ca59c06da33fe35e2
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.6.1.41152.190802.1847.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.6.1</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.0 MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2, PBE-5AC-ISO-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum bc3db8949800b465894e3ad0523fbcd8
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.6.0.40912.190618.1927.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.6.0</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.0 MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2, PBE-5AC-ISO-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 02f0dd98c3ae6c6369d666743d53fb1d
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.5.12.40181.190213.1104.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.5.12</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">8.7MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2, PBE-5AC-ISO-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 9ea4c03c042a795a3f70167fc82efef8
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.5.11.39842.190109.1449.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.5.11</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">8.7MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2, PBE-5AC-ISO-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 15aaad9f96c70dd6e2d14da29bdfd8e5
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.5.8.38845.180918.1016.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.5.8</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2, PBE-5AC-ISO-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum d5d535e47cd6840342a53839204bb79a
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.5.7.38314.180628.1036.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.5.7</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">8.5MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 079f0fb4a1c43bfbb596b2b63401e18d
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.5.4.37936.180524.1215.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">8.5MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 84dc1a3e21efa40c7d36fbf1bc0b909d
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.5.1.37185.180307.1534.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.5.1</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">8.5MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 7a64c8778ddf1168b59d06ed88e51b09
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.5.0.36727.180118.1314.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.5.0</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">8.5MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum f97d6eb25bab05b8a4c5454f89d6394e
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.4.3.36160.171117.1234.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.4.3</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.2MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 19b43ad15f1a3d2b0f78f59f873b2581
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.4.2.35930.171017.1722.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.4.2</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.2MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum f9dbec6ced4aac85bf7600dac0c4fe10
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.4.1.35794.171006.1417.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.4.1</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.2MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum bdd1f8dc29baf8363cfc07bb20525787
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.4.0.35708.170929.1512.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.4.0</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.2MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 3de551fd81fd6dc10580227d391731f8
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.3.2.35333.170901.1549.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.3.2</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.2MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum b62883c1fbe2bf95d7cff5f877c94da6
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.3.1.34976.170727.1739.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.3.1</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.0MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum a9662941855bc445640749b1a2ad1c58
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.3.34573.170614.1646.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.3.0</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">8.6MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">GPS Sync, IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum b435a7cbadb196ee3b92988f80673c31
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.1.4.34481.170608.1729.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.1.4</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">8.7MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 3b7c3d81e627fd8df7217d9adb95c65a
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.1.2.32951.170302.1840.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.1.2</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">8.5MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD% checksum b6726014ad30921623fa3760e13c2df3
#                         </div>
# </li>
# 2022-12-17 22:53:09.307 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/airmax-ac/prismstation-ac
# 2022-12-17 22:53:09.963 | DEBUG    | __main__:_find_metadata_table:90 - Clicked See past firmware button
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">XC.v8.7.11.46972.220614.0419.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.7.11</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.8MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 34411d99cdfe513c3ad65e62054a8743
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">XC.v8.7.9.46843.220329.1735.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.7.9</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.8MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 60c8ebd7f287c8d92a35a0c6e84f7d06
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">XC.v8.7.8.46705.220201.1816.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.7.8</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.8MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 5252a9586e033fb875c6313263c87bdc
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">XC.v8.7.7.46663.220119.1718.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.7.7</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.8MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum b34c8b76f1a63304fc0cdb8ae77adb95
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">XC.v8.7.5.45783.210720.1003.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.7.5</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.31MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 0E974B74384AFC13B07F4C00EECF5415
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">XC.v8.7.4.45112.210415.1103.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.7.4</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.8MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">XC.v8.7.1.42832.200623.1641.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.7.1</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.2MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum d5a24458d5d10297dccec05b98cc7d43
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">XC.v8.7.0.42152.200203.1256.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.7.0</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">8.8MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 867cbc8228cda1d661803c1ca5ee81d5
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">XC.v8.6.2.41239.190822.1633.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.6.2</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.2MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 379b7d32ca72692d0fce208af5fa202e
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">XC.v8.6.1.41152.190802.1848.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.6.1</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.2MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
# ...
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum a9662941855bc445640749b1a2ad1c58
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.3.34573.170614.1646.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.3.0</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">8.6MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">GPS Sync, IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum b435a7cbadb196ee3b92988f80673c31
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.1.4.34481.170608.1729.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.1.4</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">8.7MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 3b7c3d81e627fd8df7217d9adb95c65a
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.1.2.32951.170302.1840.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.1.2</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">8.5MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD% checksum b6726014ad30921623fa3760e13c2df3
#                         </div>
# </li>
# 2022-12-17 22:53:30.640 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/airmax-ac/powerbeam-ac
# 2022-12-17 22:53:31.293 | DEBUG    | __main__:_find_metadata_table:90 - Clicked See past firmware button
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.7.11.46972.220614.0420.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.7.11</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.7MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 855887a0a61c93e05c9448b2a3aca4d2
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">XC.v8.7.11.46972.220614.0419.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.7.11</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.8MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 34411d99cdfe513c3ad65e62054a8743
#                         </div>
# </li>
# 2022-12-17 22:53:34.056 | DEBUG    | __main__:_open_website:28 - Opened Ubiquiti website https://www.ui.com/download/airmax-ac/powerbeam-ac-gen2
# 2022-12-17 22:53:34.693 | DEBUG    | __main__:_find_metadata_table:90 - Clicked See past firmware button
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">2WA.v8.7.11.46972.220614.0419.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.7.11</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.7MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">B-DB-AC, BulletAC-IP67, NBE-2AC-13, PBE-2AC-400</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum a3b2cc26223804c42ec9ced5d03b0499
#                         </div>
# </li>
# <li class="downloadPreview__filenameTitle">
# <div class="downloadPreview__title">Filename:</div>
# <div class="downloadPreview__spec">WA.v8.7.11.46972.220614.0420.bin</div>
# </li>
# <li class="downloadPreview__type">
# <div class="downloadPreview__title">Type:</div>
# <div class="downloadPreview__spec"><span class="icon ubnt-icon--firmware-update downloadResults__typeIcon"></span>Firmware</div>
# </li>
# <li>
# <div class="downloadPreview__title">Version:</div>
# <div class="downloadPreview__spec">v8.7.11</div>
# </li>
# <li>
# <div class="downloadPreview__title">Size:</div>
# <div class="downloadPreview__spec">9.7MB</div>
# </li>
# <li class="downloadPreview__otherProducts">
# <div class="downloadPreview__title"> Products:</div>
# <div class="downloadPreview__spec">IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2</div>
# </li>
# <li class="downloadPreview__description">
# <div class="downloadPreview__title">Description:</div>
# <div class="downloadPreview__spec">
#                             MD5 checksum 855887a0a61c93e05c9448b2a3aca4d2
#                         </div>
# </li>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [194], line 5
#       3 for product_type, products in product_catalog.items():
#       4     for product in products[:10]:
# ----> 5         metadata_table = scraper._find_metadata_table(product_type, product)
#       6         firmware_list = BeautifulSoup(metadata_table, 'html.parser').find_all('ul')
#       7         for fw in firmware_list:
#
# Cell In [189], line 82, in UbiquitiScraper._find_metadata_table(self, product_type, product_url)
#      71 """ find clickable button for see all firmwares then
#      72     find metadata table in html abd return it
#      73
#    (...)
#      79     _type_:
#      80 """
#      81 # i.e. https://www.ui.com/download/airmax-ac/powerbeam-ac
# ---> 82 self._open_website(f'{VENDOR_URL}{product_type}/{product_url}')
#      83 #SELECTOR_METADATA_TABLE = '/html/body/div[1]/div[1]/div[2]/div[4]/div/main/table'
#      84 SELECTOR_METADATA_TABLE = '/html/body/div[1]/div[1]/div[2]/div[4]/div/main/table/tbody[2]'
#
# Cell In [189], line 27, in UbiquitiScraper._open_website(self, url)
#      25     if not url:
#      26         url = self.url
# ---> 27     self.driver.get(url)
#      28     self.logger.debug(f'Opened {self.name} website {url}')
#      29 except Exception as e:
#
# File /usr/local/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:455, in WebDriver.get(self, url)
#     451 def get(self, url: str) -> None:
#     452     """
#     453     Loads a web page in the current browser session.
#     454     """
# --> 455     self.execute(Command.GET, {"url": url})
#
# File /usr/local/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:442, in WebDriver.execute(self, driver_command, params)
#     439     elif "sessionId" not in params:
#     440         params["sessionId"] = self.session_id
# --> 442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
#     444     self.error_handler.check_response(response)
#
# File /usr/local/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py:294, in RemoteConnection.execute(self, command, params)
#     292 data = utils.dump_json(params)
#     293 url = f"{self._url}{path}"
# --> 294 return self._request(command_info[0], url, body=data)
#
# File /usr/local/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py:316, in RemoteConnection._request(self, method, url, body)
#     313     body = None
#     315 if self.keep_alive:
# --> 316     response = self._conn.request(method, url, body=body, headers=headers)
#     317     statuscode = response.status
#     318 else:
#
# File /usr/local/lib/python3.10/site-packages/urllib3/request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File /usr/local/lib/python3.10/site-packages/urllib3/request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File /usr/local/lib/python3.10/site-packages/urllib3/poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File /usr/local/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /usr/local/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /usr/local/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /usr/local/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File /usr/local/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/local/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/local/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
            """
            fw_attributes = fw.get_text().split(':')
            fw_attributes = [x.strip().replace('\n','') for x in fw_attributes]
            print(fw_attributes)
            print(fw_attributes[1].replace('Type', ''))
            print(fw_attributes[3].replace('Size', '')) 
            print(fw_attributes[6].replace('MD5 checksum ', ''))
            print('***')"""

# %%
ll
# Out:
# [{'Filename': 'XC.v8.7.11.46972.220614.0419.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.11',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.11.46972.220614.0419.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.11',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.11.46972.220614.0419.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.11',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.11.46972.220614.0419.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.11',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.11.46972.220614.0419.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.11',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.11.46972.220614.0419.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.11',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.9.46843.220329.1735.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.9',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.9.46843.220329.1735.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.9',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.9.46843.220329.1735.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.9',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.9.46843.220329.1735.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.9',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.9.46843.220329.1735.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.9',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.9.46843.220329.1735.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.9',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.8.46705.220201.1816.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.8',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.8.46705.220201.1816.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.8',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.8.46705.220201.1816.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.8',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.8.46705.220201.1816.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.8',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.8.46705.220201.1816.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.8',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.8.46705.220201.1816.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.8',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.7.46663.220119.1718.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.7',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.7.46663.220119.1718.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.7',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.7.46663.220119.1718.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.7',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.7.46663.220119.1718.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.7',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.7.46663.220119.1718.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.7',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.7.46663.220119.1718.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.7',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.5.45783.210720.1003.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.5',
#   'Size': '9.31MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.5.45783.210720.1003.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.5',
#   'Size': '9.31MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.5.45783.210720.1003.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.5',
#   'Size': '9.31MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.5.45783.210720.1003.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.5',
#   'Size': '9.31MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.5.45783.210720.1003.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.5',
#   'Size': '9.31MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.5.45783.210720.1003.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.5',
#   'Size': '9.31MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.4.45112.210415.1103.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.4',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2'},
#  {'Filename': 'XC.v8.7.4.45112.210415.1103.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.4',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2'},
#  {'Filename': 'XC.v8.7.4.45112.210415.1103.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.4',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2'},
#  {'Filename': 'XC.v8.7.4.45112.210415.1103.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.4',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2'},
#  {'Filename': 'XC.v8.7.4.45112.210415.1103.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.4',
#   'Size': '9.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2'},
#  {'Filename': 'XC.v8.7.1.42832.200623.1641.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.1',
#   'Size': '9.2MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.1.42832.200623.1641.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.1',
#   'Size': '9.2MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.1.42832.200623.1641.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.1',
#   'Size': '9.2MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.1.42832.200623.1641.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.1',
#   'Size': '9.2MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.1.42832.200623.1641.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.1',
#   'Size': '9.2MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.1.42832.200623.1641.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.1',
#   'Size': '9.2MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.0.42152.200203.1256.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.0',
#   'Size': '8.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.0.42152.200203.1256.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.0',
#   'Size': '8.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.0.42152.200203.1256.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.0',
#   'Size': '8.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.0.42152.200203.1256.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.0',
#   'Size': '8.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.0.42152.200203.1256.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.0',
#   'Size': '8.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.7.0.42152.200203.1256.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.7.0',
#   'Size': '8.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.6.2.41239.190822.1633.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.6.2',
#   'Size': '9.2MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.6.2.41239.190822.1633.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.6.2',
#   'Size': '9.2MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.6.2.41239.190822.1633.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.6.2',
#   'Size': '9.2MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.6.2.41239.190822.1633.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.6.2',
#   'Size': '9.2MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.6.2.41239.190822.1633.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.6.2',
#   'Size': '9.2MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.6.2.41239.190822.1633.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.6.2',
#   'Size': '9.2MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.6.1.41152.190802.1848.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.6.1',
#   'Size': '9.2MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.6.1.41152.190802.1848.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.6.1',
#   'Size': '9.2MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.6.1.41152.190802.1848.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.6.1',
#   'Size': '9.2MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.6.1.41152.190802.1848.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.6.1',
#   'Size': '9.2MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.6.1.41152.190802.1848.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.6.1',
#   'Size': '9.2MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.6.1.41152.190802.1848.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.6.1',
#   'Size': '9.2MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.6.0.40912.190618.1927.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.6.0',
#   'Size': '9.2MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.6.0.40912.190618.1927.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.6.0',
#   'Size': '9.2MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.6.0.40912.190618.1927.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.6.0',
#   'Size': '9.2MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.6.0.40912.190618.1927.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.6.0',
#   'Size': '9.2MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.6.0.40912.190618.1927.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.6.0',
#   'Size': '9.2MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.6.0.40912.190618.1927.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.6.0',
#   'Size': '9.2MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.12.40181.190213.1104.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.12',
#   'Size': '8.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.12.40181.190213.1104.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.12',
#   'Size': '8.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.12.40181.190213.1104.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.12',
#   'Size': '8.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.12.40181.190213.1104.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.12',
#   'Size': '8.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.12.40181.190213.1104.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.12',
#   'Size': '8.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.12.40181.190213.1104.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.12',
#   'Size': '8.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.11.39842.190109.1449.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.11',
#   'Size': '8.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.11.39842.190109.1449.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.11',
#   'Size': '8.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.11.39842.190109.1449.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.11',
#   'Size': '8.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.11.39842.190109.1449.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.11',
#   'Size': '8.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.11.39842.190109.1449.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.11',
#   'Size': '8.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.11.39842.190109.1449.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.11',
#   'Size': '8.8MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.8.38845.180918.1016.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.8',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.8.38845.180918.1016.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.8',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.8.38845.180918.1016.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.8',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.8.38845.180918.1016.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.8',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.8.38845.180918.1016.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.8',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.7.38314.180628.1037.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.7',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.7.38314.180628.1037.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.7',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.7.38314.180628.1037.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.7',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.7.38314.180628.1037.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.7',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.7.38314.180628.1037.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.7',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.7.38314.180628.1037.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.7',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.4.37936.180524.1215.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.4',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.4.37936.180524.1215.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.4',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.4.37936.180524.1215.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.4',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.4.37936.180524.1215.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.4',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.4.37936.180524.1215.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.4',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.4.37936.180524.1215.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.4',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.1.37185.180307.0931.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.1',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.1.37185.180307.0931.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.1',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.1.37185.180307.0931.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.1',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.1.37185.180307.0931.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.1',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.1.37185.180307.0931.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.1',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.1.37185.180307.0931.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.1',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.0.36727.180118.1402.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.0',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.0.36727.180118.1402.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.0',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.0.36727.180118.1402.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.0',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.0.36727.180118.1402.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.0',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.0.36727.180118.1402.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.0',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.5.0.36727.180118.1402.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.5.0',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.4.3.36160.171117.1233.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.4.3',
#   'Size': '9.4MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.4.3.36160.171117.1233.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.4.3',
#   'Size': '9.4MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.4.3.36160.171117.1233.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.4.3',
#   'Size': '9.4MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.4.3.36160.171117.1233.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.4.3',
#   'Size': '9.4MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.4.3.36160.171117.1233.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.4.3',
#   'Size': '9.4MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.4.3.36160.171117.1233.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.4.3',
#   'Size': '9.4MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.4.2.35930.171017.1722.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.4.2',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.4.2.35930.171017.1722.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.4.2',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.4.2.35930.171017.1722.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.4.2',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.4.2.35930.171017.1722.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.4.2',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.4.2.35930.171017.1722.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.4.2',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.4.2.35930.171017.1722.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.4.2',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.4.1.35794.171006.1417.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.4.1',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.4.1.35794.171006.1417.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.4.1',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.4.1.35794.171006.1417.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.4.1',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.4.1.35794.171006.1417.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.4.1',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.4.1.35794.171006.1417.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.4.1',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.4.1.35794.171006.1417.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.4.1',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.4.0.35708.170929.1512.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.4.0',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.4.0.35708.170929.1512.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.4.0',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.4.0.35708.170929.1512.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.4.0',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.4.0.35708.170929.1512.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.4.0',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.4.0.35708.170929.1512.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.4.0',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.4.0.35708.170929.1512.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.4.0',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.3.2.35333.170901.1549.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.3.2',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.3.2.35333.170901.1549.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.3.2',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.3.2.35333.170901.1549.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.3.2',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.3.2.35333.170901.1549.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.3.2',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.3.2.35333.170901.1549.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.3.2',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.3.2.35333.170901.1549.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.3.2',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.3.1.34976.170727.1739.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.3.1',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.3.1.34976.170727.1739.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.3.1',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.3.1.34976.170727.1739.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.3.1',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.3.1.34976.170727.1739.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.3.1',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.3.1.34976.170727.1739.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.3.1',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.3.1.34976.170727.1739.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.3.1',
#   'Size': '9.3MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.3.34573.170614.1550.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.3.0',
#   'Size': '8.6MB',
#   'Products': 'GPS Sync, NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.3.34573.170614.1550.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.3.0',
#   'Size': '8.6MB',
#   'Products': 'GPS Sync, NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.3.34573.170614.1550.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.3.0',
#   'Size': '8.6MB',
#   'Products': 'GPS Sync, NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.3.34573.170614.1550.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.3.0',
#   'Size': '8.6MB',
#   'Products': 'GPS Sync, NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.3.34573.170614.1550.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.3.0',
#   'Size': '8.6MB',
#   'Products': 'GPS Sync, NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.3.34573.170614.1550.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.3.0',
#   'Size': '8.6MB',
#   'Products': 'GPS Sync, NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.1.4.34481.170608.1728.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.1.4',
#   'Size': '8.7MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.1.4.34481.170608.1728.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.1.4',
#   'Size': '8.7MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.1.4.34481.170608.1728.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.1.4',
#   'Size': '8.7MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.1.4.34481.170608.1728.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.1.4',
#   'Size': '8.7MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.1.4.34481.170608.1728.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.1.4',
#   'Size': '8.7MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.1.4.34481.170608.1728.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.1.4',
#   'Size': '8.7MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.1.2.32951.170302.1642.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.1.2',
#   'Size': '8.7MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.1.2.32951.170302.1642.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.1.2',
#   'Size': '8.7MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.1.2.32951.170302.1642.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.1.2',
#   'Size': '8.7MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.1.2.32951.170302.1642.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.1.2',
#   'Size': '8.7MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.1.2.32951.170302.1642.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.1.2',
#   'Size': '8.7MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.1.2.32951.170302.1642.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.1.2',
#   'Size': '8.7MB',
#   'Products': 'NBE-5AC-19, NBE-5AC-Gen2, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, PS-5AC, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP, RP-5AC-Gen2',
#   'Description': ''},
#  {'Filename': 'XC.v8.0.2.33352.170327.1907.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.0.2',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP',
#   'Description': ''},
#  {'Filename': 'XC.v8.0.2.33352.170327.1907.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.0.2',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP',
#   'Description': ''},
#  {'Filename': 'XC.v8.0.2.33352.170327.1907.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.0.2',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP',
#   'Description': ''},
#  {'Filename': 'XC.v8.0.2.33352.170327.1907.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.0.2',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP',
#   'Description': ''},
#  {'Filename': 'XC.v8.0.2.33352.170327.1907.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.0.2',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP',
#   'Description': ''},
#  {'Filename': 'XC.v8.0.2.33352.170327.1907.bin',
#   'Type': 'Firmware',
#   'Version': 'v8.0.2',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP',
#   'Description': ''},
#  {'Filename': 'XC.v7.2.5.33366.170328.1556.bin',
#   'Type': 'Firmware',
#   'Version': 'v7.2.5',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP',
#   'Description': ''},
#  {'Filename': 'XC.v7.2.5.33366.170328.1556.bin',
#   'Type': 'Firmware',
#   'Version': 'v7.2.5',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP',
#   'Description': ''},
#  {'Filename': 'XC.v7.2.5.33366.170328.1556.bin',
#   'Type': 'Firmware',
#   'Version': 'v7.2.5',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP',
#   'Description': ''},
#  {'Filename': 'XC.v7.2.5.33366.170328.1556.bin',
#   'Type': 'Firmware',
#   'Version': 'v7.2.5',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP',
#   'Description': ''},
#  {'Filename': 'XC.v7.2.5.33366.170328.1556.bin',
#   'Type': 'Firmware',
#   'Version': 'v7.2.5',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP',
#   'Description': ''},
#  {'Filename': 'XC.v7.2.5.33366.170328.1556.bin',
#   'Type': 'Firmware',
#   'Version': 'v7.2.5',
#   'Size': '8.5MB',
#   'Products': 'NBE-5AC-19, PBE-5AC-500, PBE-5AC-500-ISO, PBE-5AC-620, R5AC-Lite, R5-AC-PRISM, R5AC-PTMP, R5AC-PTP',
#   'Description': ''}]

# %%
# Out:
# GBE.v1.4.1.1bf05681.221028.1153.bin
# v1.4.1
# 1b67fd49247d811cede8aeff7bf2b061
# ***
# GBE.v1.4.0.1e71455a.210726.1326.bin
# v1.4.0
# 47c9ce60f95f7018297c76af75ac3056
# ***
# GBE.v1.3.0.492789c1.210406.0813.bin
# v1.3.0
# 81f8dc779f424512c46fe362ce26be57
# ***
# GBE.v1.2.0.ec5ea39c.201015.1407.bin
# v1.2.0
# 730066aeed53dab323f090973f5cb7a6
# ***
# GBE.v0.11.1-cs.f16f621c.200826.1546.bin
# v0.11.1
# 99d7216db91e4c54da426d28d4cf43d0
# ***

# %%
import BeautifiulSoup
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [109], line 1
# ----> 1 import BeautifiulSoup
#
# ModuleNotFoundError: No module named 'BeautifiulSoup'

# %%
def get_product_type_list(self) -> list:
        """parses html and returns a list of tuples with product name and product url

        Args:
            html (_type_): html of current product list

        Returns:
            list: list of tuples with product name and product url
        """    
        SELECTOR_PRODUCT_TYPE = '//*[@id="downloads"]/div[1]'
        self.driver.implicitly_wait(1)
        html = self.driver.find_element(By.XPATH, value=SELECTOR_PRODUCT_TYPE).get_attribute('innerHTML')
        product_list = BeautifulSoup(html, 'html.parser').find_all('li')
        products_tuple_list = [] # list of tuples with product name and product url
        for product in product_list:
            product_name = product.find_all('a')[0]['data-title']
            # append product name and product url
            products_tuple_list.append((product_name, f"{VENDOR_URL}{product_name.lower().replace(' ', '-')}"))
        
        return products_tuple_list

# %%
def _create_product_catalog(self) -> list:
        """parses html and returns a list of tuples with product name and product url

        Args:
            html (_type_): html of current product list

        Returns:
            list: list of tuples with product name and product url
        """

        SELECTOR_PRODUCTS = '//*[@id="downloads"]/div[2]/div[1]'
        self.driver.implicitly_wait(1)
        html = self.driver.find_element(By.XPATH, value=SELECTOR_PRODUCTS).get_attribute('innerHTML')
        product_type_list = BeautifulSoup(html, 'html.parser').find_all('li') # list of product_types
        # list of tuples (product name, product url)
        p_type_and_p_name_tuple = []
        for elem in product_type_list:
            for elem2 in elem('a'):
                try:
                    p_type_and_p_name_tuple.append((elem2.find_all('span')[-1].text, elem2['href']))
                except Exception as e:
                    print(e)
        # list of tuples (product name, product url) to product catalog dict
        for product in p_type_and_p_name_tuple:
            if product[1].startswith('#!'):
                product_type = product[1].replace('#!', '')
                self.product_catalog[product_type] = []
            else:
                self.product_catalog[product_type].append(product[1].replace('#', ''))
        # clean up product catalog, no empty lists like in training, utilities
        self.product_catalog = {k: v for k, v in self.product_catalog.items() if v}
        return self.product_catalog

# %%
product_catalog = create_product_catalog(scraper)
# Out:
# list index out of range
# list index out of range

# %%
def find_metadata_table(self, product_type:str, product_url: str):
    """ find clickable button for see all firmwares then
        find metadata table in html abd return it

    Args:
        product_type (str): product type
        product_url (str): product url / product name

    Returns:
        _type_: 
    """        
    # i.e. https://www.ui.com/download/airmax-ac/powerbeam-ac
    self._open_website(f'{VENDOR_URL}{product_type}/{product_url}')
    #SELECTOR_METADATA_TABLE = '/html/body/div[1]/div[1]/div[2]/div[4]/div/main/table'
    SELECTOR_METADATA_TABLE = '/html/body/div[1]/div[1]/div[2]/div[4]/div/main/table/tbody[2]'
    SELECTOR_PAST_FW_BUTTON = '//*[@id="downloads"]/div[2]/div[4]/div/main/table/tbody[2]/tr[4]/td/a'
    self.driver.implicitly_wait(1)
    try:
        self.driver.find_element(
            By.XPATH, value=SELECTOR_PAST_FW_BUTTON).click()
    except Exception as e:
        self.logger.debug('No past firmware button, searching for metadata table')
    try:
        product_metadata = self.driver.find_element(
            By.XPATH, value=SELECTOR_METADATA_TABLE).get_attribute('innerHTML')
        self.driver.implicitly_wait(1)
        return product_metadata
    except Exception as e:
        self.logger.debug('No metadata table, skip product')
        return None

# %%
# get first key from dicrionary
list(product_catalog.keys())[0], product_catalog[list(product_catalog.keys())[0]][0]
# Out:
# ('airmax-ac', 'gigabeam')

# %%
table = find_metadata_table(scraper, list(product_catalog.keys())[0], product_catalog[list(product_catalog.keys())[0]][1])
# Out:
# 2022-12-16 11:26:22.799 | DEBUG    | __main__:_open_website:27 - Opened Ubiquiti website https://www.ui.com/download/airmax-ac/isostation-ac

# %%
def scrape_metadata(self):
    """scrapes metadata from foscam website

    Returns:
        list[dict]: list of dicts with metadata
    """
    self._open_website()
    self._create_product_catalog()

    metadata = []
    self.logger.debug(f'Iterate over product catalog and scrape metadata')
    for product, product_url in self.products_list:
        if len(metadata) > self.max_products:
            break
        try:
            self._open_website(f'{VENDOR_URL}{product_url}')
            metadata_html = self._find_metadata_table(product_url)
            fw_releases_list = BeautifulSoup(
                metadata_html, 'html.parser').find_all('tr')
            for fw_release in fw_releases_list[1:]:
                metadata_current = fw_release.find_all('td')
                tmp_metadata_dict = {'manufacturer': 'foscam',
                                        'version': metadata_current[0].text,
                                        'product_type': None,  # not available
                                        'product_name': product,
                                        'url': f'{VENDOR_URL}{product_url}',
                                        'checksum_scraped': None,  # not available
                                        'download_link': f"{VENDOR_URL}{metadata_current[-1].find_all('a')[0]['href']}",
                                        'release_date': self._convert_date(metadata_current[1].text),
                                        "additional_data": {}  # nothing valuable
                                        }

                metadata.append(tmp_metadata_dict)
            print(f'Finished scraping {product=}, {product_url=}')
        except Exception as ex:
            self.logger.debug(
                f'{product=}, {product_url=} is missing crucial data')
            self.logger.debug(ex)
            pass
        time.sleep(1)
    self.driver.quit()
    return metadata

# %%
for firmware_elem in BeautifulSoup (table, 'html.parser').find_all('li'):
    for tag in firmware_elem:
        print(tag.text)
    print('***')
# Out:
# Filename:
#
#
# WA.v8.7.11.46972.220614.0420.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Version:
#
#
# v8.7.11
#
#
# ***
#
#
# Size:
#
#
# 9.7MB
#
#
# ***
#
#
#  Products:
#
#
# IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD5 checksum 855887a0a61c93e05c9448b2a3aca4d2
#
#
#
# ***
#
#
# Filename:
#
#
# WA.v8.7.9.46843.220329.1728.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Version:
#
#
# v8.7.9
#
#
# ***
#
#
# Size:
#
#
# 9.7MB
#
#
# ***
#
#
#  Products:
#
#
# IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD5 checksum 8f855b17ee0995c67dc323b3394e631b
#
#
#
# ***
#
#
# Filename:
#
#
# WA.v8.7.8.46705.220201.1819.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Version:
#
#
# v8.7.8
#
#
# ***
#
#
# Size:
#
#
# 9.7MB
#
#
# ***
#
#
#  Products:
#
#
# IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD5 checksum bc6b35314110a4278ecd3dfeb8b28a52
#
#
#
# ***
#
#
# Filename:
#
#
# WA.v8.7.7.46663.220119.1718.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Version:
#
#
# v8.7.7
#
#
# ***
#
#
# Size:
#
#
# 9.7MB
#
#
# ***
#
#
#  Products:
#
#
# IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD5 checksum 634210d31b971d57d6cf46db5c944bd2
#
#
#
# ***
#
#
# Filename:
#
#
# WA.v8.7.5.45783.210720.1004.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Version:
#
#
# v8.7.5
#
#
# ***
#
#
# Size:
#
#
# 9.29MB
#
#
# ***
#
#
#  Products:
#
#
# IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2, PBE-5AC-ISO-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD5 checksum 02CB1D65ED9BF9240D6FA853A595F197
#
#
#
# ***
#
#
# Filename:
#
#
# WA.v8.7.4.45112.210415.1103.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Version:
#
#
# v8.7.4
#
#
# ***
#
#
# Size:
#
#
# 9.7MB
#
#
# ***
#
#
#  Products:
#
#
# IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2, PBE-5AC-ISO-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD5 checksum bb8c08affb1d248201fb8aa3764890d8
#
#
#
# ***
#
#
# Filename:
#
#
# WA.v8.7.1.42832.200623.1641.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Version:
#
#
# v8.7.1
#
#
# ***
#
#
# Size:
#
#
# 9.2MB
#
#
# ***
#
#
#  Products:
#
#
# IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2, PBE-5AC-ISO-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD5 checksum 9115c4bb55848ef881edb76c74e6575e
#
#
#
# ***
#
#
# Filename:
#
#
# WA.v8.7.0.42152.200203.1256.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Version:
#
#
# v8.7.0
#
#
# ***
#
#
# Size:
#
#
# 8.8MB
#
#
# ***
#
#
#  Products:
#
#
# IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2, PBE-5AC-ISO-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD5 checksum d1531fcd5991af73047fab83c0d016cf
#
#
#
# ***
#
#
# Filename:
#
#
# WA.v8.6.2.41239.190822.1633.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Version:
#
#
# v8.6.2
#
#
# ***
#
#
# Size:
#
#
# 9.0 MB
#
#
# ***
#
#
#  Products:
#
#
# IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2, PBE-5AC-ISO-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD5 checksum 494d0bc0307e318ca59c06da33fe35e2
#
#
#
# ***
#
#
# Filename:
#
#
# WA.v8.6.1.41152.190802.1847.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Version:
#
#
# v8.6.1
#
#
# ***
#
#
# Size:
#
#
# 9.0 MB
#
#
# ***
#
#
#  Products:
#
#
# IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2, PBE-5AC-ISO-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD5 checksum bc3db8949800b465894e3ad0523fbcd8
#
#
#
# ***
#
#
# Filename:
#
#
# WA.v8.6.0.40912.190618.1927.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Version:
#
#
# v8.6.0
#
#
# ***
#
#
# Size:
#
#
# 9.0 MB
#
#
# ***
#
#
#  Products:
#
#
# IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2, PBE-5AC-ISO-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD5 checksum 02f0dd98c3ae6c6369d666743d53fb1d
#
#
#
# ***
#
#
# Filename:
#
#
# WA.v8.5.12.40181.190213.1104.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Version:
#
#
# v8.5.12
#
#
# ***
#
#
# Size:
#
#
# 8.7MB
#
#
# ***
#
#
#  Products:
#
#
# IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2, PBE-5AC-ISO-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD5 checksum 9ea4c03c042a795a3f70167fc82efef8
#
#
#
# ***
#
#
# Filename:
#
#
# WA.v8.5.11.39842.190109.1449.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Version:
#
#
# v8.5.11
#
#
# ***
#
#
# Size:
#
#
# 8.7MB
#
#
# ***
#
#
#  Products:
#
#
# IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, LBE-5AC-LR, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2, PBE-5AC-ISO-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD5 checksum 15aaad9f96c70dd6e2d14da29bdfd8e5
#
#
#
# ***
#
#
# Filename:
#
#
# WA.v8.5.8.38845.180918.1016.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Version:
#
#
# v8.5.8
#
#
# ***
#
#
#  Products:
#
#
# IS-5AC, LAP-120, LAP-GPS, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2, PBE-5AC-ISO-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD5 checksum d5d535e47cd6840342a53839204bb79a
#
#
#
# ***
#
#
# Filename:
#
#
# WA.v8.5.7.38314.180628.1036.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Version:
#
#
# v8.5.7
#
#
# ***
#
#
# Size:
#
#
# 8.5MB
#
#
# ***
#
#
#  Products:
#
#
# IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD5 checksum 079f0fb4a1c43bfbb596b2b63401e18d
#
#
#
# ***
#
#
# Filename:
#
#
# WA.v8.5.4.37936.180524.1215.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Size:
#
#
# 8.5MB
#
#
# ***
#
#
#  Products:
#
#
# IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, NBE-5AC-Gen2, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD5 checksum 84dc1a3e21efa40c7d36fbf1bc0b909d
#
#
#
# ***
#
#
# Filename:
#
#
# WA.v8.5.1.37185.180307.1534.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Version:
#
#
# v8.5.1
#
#
# ***
#
#
# Size:
#
#
# 8.5MB
#
#
# ***
#
#
#  Products:
#
#
# IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, NS-5AC, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD5 checksum 7a64c8778ddf1168b59d06ed88e51b09
#
#
#
# ***
#
#
# Filename:
#
#
# WA.v8.5.0.36727.180118.1314.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Version:
#
#
# v8.5.0
#
#
# ***
#
#
# Size:
#
#
# 8.5MB
#
#
# ***
#
#
#  Products:
#
#
# IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD5 checksum f97d6eb25bab05b8a4c5454f89d6394e
#
#
#
# ***
#
#
# Filename:
#
#
# WA.v8.4.3.36160.171117.1234.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Version:
#
#
# v8.4.3
#
#
# ***
#
#
# Size:
#
#
# 9.2MB
#
#
# ***
#
#
#  Products:
#
#
# IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD5 checksum 19b43ad15f1a3d2b0f78f59f873b2581
#
#
#
# ***
#
#
# Filename:
#
#
# WA.v8.4.2.35930.171017.1722.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Version:
#
#
# v8.4.2
#
#
# ***
#
#
# Size:
#
#
# 9.2MB
#
#
# ***
#
#
#  Products:
#
#
# IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD5 checksum f9dbec6ced4aac85bf7600dac0c4fe10
#
#
#
# ***
#
#
# Filename:
#
#
# WA.v8.4.1.35794.171006.1417.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Version:
#
#
# v8.4.1
#
#
# ***
#
#
# Size:
#
#
# 9.2MB
#
#
# ***
#
#
#  Products:
#
#
# IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD5 checksum bdd1f8dc29baf8363cfc07bb20525787
#
#
#
# ***
#
#
# Filename:
#
#
# WA.v8.4.0.35708.170929.1512.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Version:
#
#
# v8.4.0
#
#
# ***
#
#
# Size:
#
#
# 9.2MB
#
#
# ***
#
#
#  Products:
#
#
# IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD5 checksum 3de551fd81fd6dc10580227d391731f8
#
#
#
# ***
#
#
# Filename:
#
#
# WA.v8.3.2.35333.170901.1549.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Version:
#
#
# v8.3.2
#
#
# ***
#
#
# Size:
#
#
# 9.2MB
#
#
# ***
#
#
#  Products:
#
#
# IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD5 checksum b62883c1fbe2bf95d7cff5f877c94da6
#
#
#
# ***
#
#
# Filename:
#
#
# WA.v8.3.1.34976.170727.1739.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Version:
#
#
# v8.3.1
#
#
# ***
#
#
# Size:
#
#
# 9.0MB
#
#
# ***
#
#
#  Products:
#
#
# IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD5 checksum a9662941855bc445640749b1a2ad1c58
#
#
#
# ***
#
#
# Filename:
#
#
# WA.v8.3.34573.170614.1646.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Version:
#
#
# v8.3.0
#
#
# ***
#
#
# Size:
#
#
# 8.6MB
#
#
# ***
#
#
#  Products:
#
#
# GPS Sync, IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD5 checksum b435a7cbadb196ee3b92988f80673c31
#
#
#
# ***
#
#
# Filename:
#
#
# WA.v8.1.4.34481.170608.1729.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Version:
#
#
# v8.1.4
#
#
# ***
#
#
# Size:
#
#
# 8.7MB
#
#
# ***
#
#
#  Products:
#
#
# IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD5 checksum 3b7c3d81e627fd8df7217d9adb95c65a
#
#
#
# ***
#
#
# Filename:
#
#
# WA.v8.1.2.32951.170302.1840.bin
#
#
# ***
#
#
# Type:
#
#
# Firmware
#
#
# ***
#
#
# Version:
#
#
# v8.1.2
#
#
# ***
#
#
# Size:
#
#
# 8.5MB
#
#
# ***
#
#
#  Products:
#
#
# IS-5AC, LAP-120, LBE-5AC-23, LBE-5AC-Gen2, Loco5AC, NBE-5AC-16, PBE-5AC-300, PBE-5AC-300-ISO, PBE-5AC-400, PBE-5AC-400-ISO, PBE-5AC-Gen2
#
#
# ***
#
#
# Description:
#
#
#
#                             MD% checksum b6726014ad30921623fa3760e13c2df3
#
#
#
# ***

# %%
if __name__ == '__main__':
    from loguru import logger
    import json 
    logger.debug('Start Ubiquiti')
    
    metadata = scraper.scrape_metadata()
    
    # save metadata to json file
    with open("scraped_metadata/firmware_data_foscam.json", "w") as firmware_file:
        json.dump(metadata, firmware_file)

    scraper.logger.debug(f'Finished {scraper.name}')
# Out:
# 2022-12-11 19:52:11.767 | DEBUG    | __main__:<module>:4 - Start foscam
# 2022-12-11 19:53:52.104 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/index.html
# 2022-12-11 19:53:52.108 | DEBUG    | __main__:_create_product_catalog:86 - get html of product caroussel
# 2022-12-11 19:53:52.109 | DEBUG    | __main__:_create_product_catalog:89 - Iterare over pages to create product catalog
# 2022-12-11 19:54:07.727 | DEBUG    | __main__:_next_page:73 - No next page
# 2022-12-11 19:54:07.728 | DEBUG    | __main__:_next_page:74 - Found counter=7 pages
# 2022-12-11 19:54:07.729 | DEBUG    | __main__:scrape_metadata:136 - Iterate over product catalog and scrape metadata
# 2022-12-11 19:54:08.324 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=161
# 2021/12/08
# 2022/10/26
# Finished scraping product='VD1/DBW5', product_url='/downloads/firmware_details.html?id=161'
# 2022-12-11 19:54:09.791 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=163
# 2021/12/08
# 2022/10/26
# Finished scraping product='F41/FLC', product_url='/downloads/firmware_details.html?id=163'
# 2022-12-11 19:54:11.231 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=162
# 2021/12/08
# 2022/10/26
# Finished scraping product='S41/SPC', product_url='/downloads/firmware_details.html?id=162'
# 2022-12-11 19:54:12.658 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=148
# 2021/5/10
# Finished scraping product='C2M/C2M V2/C2M V3', product_url='/downloads/firmware_details.html?id=148'
# 2022-12-11 19:54:14.074 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=134
# 2022/3/30
# 2022/05/26
# Finished scraping product='R2M', product_url='/downloads/firmware_details.html?id=134'
# 2022-12-11 19:54:15.482 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=143
# 2022/4/25
# 2022/05/26
# Finished scraping product='R4M', product_url='/downloads/firmware_details.html?id=143'
# 2022-12-11 19:54:16.942 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=135
# 2022/4/28
# Finished scraping product='FI9926P', product_url='/downloads/firmware_details.html?id=135'
# 2022-12-11 19:54:18.348 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=132
# 2022/3/30
# 2022/05/26
# Finished scraping product='FI9902P', product_url='/downloads/firmware_details.html?id=132'
# 2022-12-11 19:54:19.745 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=137
# 2022/4/25
# 2022/05/26
# Finished scraping product='G4', product_url='/downloads/firmware_details.html?id=137'
# 2022-12-11 19:54:21.248 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=144
# 2022/4/25
# 2022/05/26
# Finished scraping product='G4P', product_url='/downloads/firmware_details.html?id=144'
# 2022-12-11 19:54:23.747 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=142
# 2022/4/25
# 2022/05/26
# Finished scraping product='G4EP', product_url='/downloads/firmware_details.html?id=142'
# 2022-12-11 19:54:25.458 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=156
# 2022/4/25
# 2022/05/26
# Finished scraping product='D4Z/VZ4', product_url='/downloads/firmware_details.html?id=156'
# 2022-12-11 19:54:27.123 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=154
# 2022/4/25
# 2022/05/26
# Finished scraping product='SD2X', product_url='/downloads/firmware_details.html?id=154'
# 2022-12-11 19:54:28.737 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=155
# 2022/04/25
# 2022/05/26
# Finished scraping product='SD2/HT2', product_url='/downloads/firmware_details.html?id=155'
# 2022-12-11 19:54:30.138 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=62
# 2022/4/28
# Finished scraping product='FI9928P', product_url='/downloads/firmware_details.html?id=62'
# 2022-12-11 19:54:31.544 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=141
# 2022/3/30
# 2022/05/26
# Finished scraping product='G2EP', product_url='/downloads/firmware_details.html?id=141'
# 2022-12-11 19:54:32.986 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=151
# 2022/3/30
# 2022/05/26
# Finished scraping product='D2EP', product_url='/downloads/firmware_details.html?id=151'
# 2022-12-11 19:54:34.430 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=159
# 2022/09/23
# Finished scraping product='FN7108W-B4', product_url='/downloads/firmware_details.html?id=159'
# 2022-12-11 19:54:35.861 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=43
# 2019/07/25
# 2018/11/20
# 2018/5/17
# 2018/5/17
# 2017/07/07
# 2015/03/16
# 2014/12/22
# 2014/05/16
# 2014/04/08
# 2014/02/19
# 2013/11/13
# 2013/08/22
# Finished scraping product='FI9821W V2', product_url='/downloads/firmware_details.html?id=43'
# 2022-12-11 19:54:37.251 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=1
# 2018/10/16
# Finished scraping product='C1/C1 V2', product_url='/downloads/firmware_details.html?id=1'
# 2022-12-11 19:54:38.655 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=2
# 2018/10/16
# Finished scraping product='C1 Lite/C1 Lite V2', product_url='/downloads/firmware_details.html?id=2'
# 2022-12-11 19:54:40.120 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=3
# 2022/4/28
# Finished scraping product='FI9900P', product_url='/downloads/firmware_details.html?id=3'
# 2022-12-11 19:54:41.542 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=4
# 2022/4/28
# Finished scraping product='FI9961EP', product_url='/downloads/firmware_details.html?id=4'
# 2022-12-11 19:54:42.956 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=5
# 2022-12-11 19:54:42.998 | ERROR    | __main__:_convert_date:122 - Could not convert date 2014/01/02
# 2022-12-11 19:54:42.999 | ERROR    | __main__:_convert_date:123 - unconverted data remains:
# 2019/07/25
# 2018/11/20
# 2018/5/17
# 2018/5/17
# 2017/07/07
# 2015/03/16
# 2014/12/22
# 2014/05/16
# 2014/04/10
# 2014/02/13
# 2014/01/02
# 2013/09/22
# Finished scraping product='FI9821P', product_url='/downloads/firmware_details.html?id=5'
# 2022-12-11 19:54:44.394 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=6
# 2019/07/25
# 2018/11/20
# 2018/5/17
# 2018/5/17
# 2017/07/07
# 2015/03/16
# 2014/12/22
# 2014/08/05
# Finished scraping product='FI9831P', product_url='/downloads/firmware_details.html?id=6'
# 2022-12-11 19:54:45.810 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=7
# 2022-12-11 19:54:45.845 | ERROR    | __main__:_convert_date:122 - Could not convert date 2014/05/16
# 2022-12-11 19:54:45.846 | ERROR    | __main__:_convert_date:123 - unconverted data remains:
# 2019/07/25
# 2018/11/20
# 2018/5/17
# 2018/5/17
# 2017/07/07
# 2015/03/16
# 2014/12/22
# 2014/05/16
# 2014/04/10
# Finished scraping product='FI9826P', product_url='/downloads/firmware_details.html?id=7'
# 2022-12-11 19:54:47.291 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=8
# 2018/10/16
# Finished scraping product='FI9816P/FI9816P V2', product_url='/downloads/firmware_details.html?id=8'
# 2022-12-11 19:54:48.740 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=11
# 2022/4/28
# Finished scraping product='C2', product_url='/downloads/firmware_details.html?id=11'
# 2022-12-11 19:54:50.191 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=12
# 2019/07/25
# 2018/11/19
# 2018/5/11
# 2017/6/14
# Finished scraping product='FI9821EP', product_url='/downloads/firmware_details.html?id=12'
# 2022-12-11 19:54:51.688 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=13
# 2018/5/11
# 2016/05/26
# Finished scraping product='FosBaby', product_url='/downloads/firmware_details.html?id=13'
# 2022-12-11 19:54:53.132 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=14
# 2018/5/11
# 2016/05/26
# Finished scraping product='FosBaby P1', product_url='/downloads/firmware_details.html?id=14'
# 2022-12-11 19:54:54.534 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=15
# 2022/4/28
# Finished scraping product='R4', product_url='/downloads/firmware_details.html?id=15'
# 2022-12-11 19:54:55.997 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=16
# 2019/07/25
# 2018/11/19
# 2018/5/11
# 2017/6/14
# Finished scraping product='FI9803EP', product_url='/downloads/firmware_details.html?id=16'
# 2022-12-11 19:54:57.416 | DEBUG    | __main__:_open_website:26 - Opened foscam website https://www.foscam.com/downloads/firmware_details.html?id=120
# 2017/08/30
# Finished scraping product='FI9800E', product_url='/downloads/firmware_details.html?id=120'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [24], line 6
#       4 logger.debug('Start foscam')
#       5 foscam = FoscamScraper(logger)
# ----> 6 metadata = foscam.scrape_metadata()
#       8 # save metadata to json file
#       9 with open("scraped_metadata/firmware_data_foscam.json", "w") as firmware_file:
#
# Cell In [22], line 141, in FoscamScraper.scrape_metadata(self)
#     139         break
#     140 try:
# --> 141     self._open_website(f'https://www.foscam.com{product_url}')
#     142     metadata_html = self._find_metadata_table(product_url)
#     143     fw_releases_list = BeautifulSoup(metadata_html, 'html.parser').find_all('tr')
#
# Cell In [22], line 25, in FoscamScraper._open_website(self, url)
#      23     if not url:
#      24         url = self.url
# ---> 25     self.driver.get(url)
#      26     self.logger.debug(f'Opened foscam website {url}')
#      27 except Exception as e:
#
# File /usr/local/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:455, in WebDriver.get(self, url)
#     451 def get(self, url: str) -> None:
#     452     """
#     453     Loads a web page in the current browser session.
#     454     """
# --> 455     self.execute(Command.GET, {"url": url})
#
# File /usr/local/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:442, in WebDriver.execute(self, driver_command, params)
#     439     elif "sessionId" not in params:
#     440         params["sessionId"] = self.session_id
# --> 442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
#     444     self.error_handler.check_response(response)
#
# File /usr/local/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py:294, in RemoteConnection.execute(self, command, params)
#     292 data = utils.dump_json(params)
#     293 url = f"{self._url}{path}"
# --> 294 return self._request(command_info[0], url, body=data)
#
# File /usr/local/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py:316, in RemoteConnection._request(self, method, url, body)
#     313     body = None
#     315 if self.keep_alive:
# --> 316     response = self._conn.request(method, url, body=body, headers=headers)
#     317     statuscode = response.status
#     318 else:
#
# File /usr/local/lib/python3.10/site-packages/urllib3/request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File /usr/local/lib/python3.10/site-packages/urllib3/request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File /usr/local/lib/python3.10/site-packages/urllib3/poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File /usr/local/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /usr/local/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /usr/local/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /usr/local/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File /usr/local/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/local/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/local/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
ll
# Out:
# []
